# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv('datasets/avocado.csv')

# %% [markdown]
# ### Avocado
# Hierboven wordt een dataset ingeladen. Deze dataset bevat informatie over de verkoop van avocado's in verschillende regio's.

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
min_prices = data.groupby('region')['AveragePrice'].min()
max_prices = data.groupby('region')['AveragePrice'].max()
avg_prices = data.groupby('region')['AveragePrice'].mean()
output = pd.merge(min_prices, max_prices ,on='region')
output = pd.merge(output, avg_prices, on='region')
output.columns = ['min_price', 'max_price', 'mean_price']

# %% [markdown]
# Hierboven wordt van de originele data een nieuwe tabel samengesteld.

# %%
cost_data = data.query('region == "Albany" ')
grouped_data = cost_data.groupby('year')['AveragePrice'].unique()

data1 = grouped_data.iloc[0] #2015
data2 = grouped_data.iloc[1] #2016
data3 = grouped_data.iloc[2] #2017
data4 = grouped_data.iloc[3] #2018

plt.figure(figsize=(5, 5))
plt.plot(data1, 'r')
plt.plot(data2, 'g')
plt.plot(data3, 'b')
plt.plot(data4, 'y')
plt.title('Avocado price fluctuations per year for Albany')
plt.legend(['2015', '2016', '2017', '2018']);

print(data1.min());
# Out:
# 0.93

# %%
cost_data = data.query('region == "Atlanta" ')
grouped_data = cost_data.groupby('year')['AveragePrice'].unique()

data1 = grouped_data.iloc[0] #2015
data2 = grouped_data.iloc[1] #2016
data3 = grouped_data.iloc[2] #2017
data4 = grouped_data.iloc[3] #2018

plt.figure(figsize=(5, 5))
plt.plot(data1, 'r')
plt.plot(data2, 'g')
plt.plot(data3, 'b')
plt.plot(data4, 'y')
plt.title('Avocado price fluctuations per year for Atlanta')
plt.legend(['2015', '2016', '2017', '2018']);

print(data1.min());
# Out:
# 0.93
